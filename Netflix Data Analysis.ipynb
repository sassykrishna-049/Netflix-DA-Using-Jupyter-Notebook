# %%
## Importing the dataset

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

df_netflix = pd.read_csv(r"C:\Users\ACER\Desktop\Krishna\Python Scripts\Projects\8. Netflix Dataset.csv",encoding = 'unicode_escape')


## if anyone is getting the unicode escape error ,pls declare the dataset like I have done in the above manner .
##The encoding parameter is set to 'unicode_escape' to ensure that any non-ASCII characters in the CSV file are properly decoded.

# %%
df_netflix
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  JoÃ£o Miguel, Bianca Comparato, Michel Gomes, ...
# ...

# %%
## getting some basic information about our dataset
df_netflix.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  JoÃ£o Miguel, Bianca Comparato, Michel Gomes, ...         Brazil
# 1  DemiÃ¡n Bichir, HÃ©ctor Bonilla, Oscar Serrano...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
df_netflix.tail()
# Out:
#      Show_Id Category                                    Title     Director  \
# 7784   s7783    Movie                                     Zozo  Josef Fares
# 7785   s7784    Movie                                   Zubaan  Mozez Singh
# 7786   s7785    Movie                        Zulu Man in Japan          NaN
# 7787   s7786  TV Show                    Zumbo's Just Desserts          NaN
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS     Sam Dunn
#
#                                                    Cast  \
# 7784  Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 7785  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# 7786                                            Nasty C
# 7787                         Adriano Zumbo, Rachel Khoo
# 7788                                                NaN
#
#                                                 Country        Release_Date  \
# 7784  Sweden, Czech Republic, United Kingdom, Denmar...    October 19, 2020
# ...

# %%
df_netflix.info()                ## to shows indexes, columns, data types of each columns at once.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   object
#  1   Category      7789 non-null   object
#  2   Title         7789 non-null   object
#  3   Director      5401 non-null   object
#  4   Cast          7071 non-null   object
#  5   Country       7282 non-null   object
#  6   Release_Date  7779 non-null   object
#  7   Rating        7782 non-null   object
#  8   Duration      7789 non-null   object
#  9   Type          7789 non-null   object
#  10  Description   7789 non-null   object
# dtypes: object(11)
# memory usage: 669.5+ KB

# %%
df_netflix.size ## total number of elements
# Out:
# 85679

# %%
df_netflix.columns   ## shows the names of the columns
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %%
df_netflix.dtypes                 ## to show  the data types of all the columns
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %%
### is there any duplicate values

print(df_netflix.duplicated().sum())
# Out:
# 2

# %%
df_netflix[df_netflix.duplicated()]
# Out:
#      Show_Id Category              Title        Director  \
# 6300    s684    Movie           Backfire     Dave Patten
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#            Release_Date Rating Duration  \
# 6300      April 5, 2019  TV-MA   97 min
# 6622  September 4, 2020  TV-MA   94 min
#
#                                        Type  \
# 6300  Dramas, Independent Movies, Thrillers
# 6622   Comedies, Dramas, Independent Movies
#
#                                             Description
# 6300  When two would-be robbers accidentally kill a ...
# 6622  A disillusioned security guard transforms into...

# %%
## To remove dupplicates
df_netflix=df_netflix.drop_duplicates()

# %%
df_netflix.shape ## we can see the shape has changed, that means the duplicates are removed
# Out:
# (7787, 11)

# %%
## is there any null value present ? Shwo that with a heat map
df_netflix.isnull().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
 ## To see how much percentage of data is absent in each column
(df_netflix.isnull().sum()/len(df_netflix)*100).sort_values(ascending = False)
# Out:
# Director        30.666495
# Cast             9.220496
# Country          6.510851
# Release_Date     0.128419
# Rating           0.089893
# Show_Id          0.000000
# Category         0.000000
# Title            0.000000
# Duration         0.000000
# Type             0.000000
# Description      0.000000
# dtype: float64

# %%
sns.heatmap(df_netflix.isnull())
# Out:
# <Axes: >

# %%
## 1. For the show " house of cards" find the details of it 
df_netflix[df_netflix['Title'].isin(['House of Cards'])]
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %%
## using str.contains
df_netflix[df_netflix['Title'].str.contains('House of Cards')]
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %% [markdown]
# ###  In which year the highest number of TV shows or movies were released

# %%
df_netflix.dtypes  ## here the release date is in object , we need to convert it to date data - type
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %%
df_netflix.loc[:, 'Release Year'] = pd.to_datetime(df_netflix['Release_Date'], format='mixed')
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_14492\1256386415.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_netflix.loc[:, 'Release Year'] = pd.to_datetime(df_netflix['Release_Date'], format='mixed')

# %%
df_netflix.dtypes
# Out:
# Show_Id                 object
# Category                object
# Title                   object
# Director                object
# Cast                    object
# Country                 object
# Release_Date            object
# Rating                  object
# Duration                object
# Type                    object
# Description             object
# Release Year    datetime64[ns]
# dtype: object

# %%
df_netflix['Release Year'].dt.year.value_counts() ## it counts the occurence of all individual yearsd in date column
# Out:
# Release Year
# 2019.0    2153
# 2020.0    2009
# 2018.0    1685
# 2017.0    1225
# 2016.0     443
# 2021.0     117
# 2015.0      88
# 2014.0      25
# 2011.0      13
# 2013.0      11
# 2012.0       3
# 2008.0       2
# 2009.0       2
# 2010.0       1
# Name: count, dtype: int64

# %%
df_netflix['Release Year'].dt.year.value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Release Year'>

# %% [markdown]
# #### How many movies and tv swows are there in dataset? show with bar graphs

# %%
df_netflix.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  JoÃ£o Miguel, Bianca Comparato, Michel Gomes, ...         Brazil
# 1  DemiÃ¡n Bichir, HÃ©ctor Bonilla, Oscar Serrano...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
df_netflix.groupby('Category').Category.count()
# Out:
# Category
# Movie      5377
# TV Show    2410
# Name: Category, dtype: int64

# %%
sns.countplot(data=df_netflix, x='Category')
# Out:
# <Axes: xlabel='Category', ylabel='count'>

# %% [markdown]
# ####  Q. 4. Show all the movies released in the year 2020

# %%
df_netflix.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  JoÃ£o Miguel, Bianca Comparato, Michel Gomes, ...         Brazil
# 1  DemiÃ¡n Bichir, HÃ©ctor Bonilla, Oscar Serrano...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
## Creating new column  
    
df_netflix['Year']=df_netflix['Release Year'].dt.year
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_14492\1435774131.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_netflix['Year']=df_netflix['Release Year'].dt.year

# %%
df_movies_in_2020=df_netflix[(df_netflix['Year'] == 2020) & (df_netflix['Category']=='Movie')]

# %%
df_movies_in_2020
# Out:
#      Show_Id Category                                    Title  \
# 4         s5    Movie                                       21
# 6         s7    Movie                                      122
# 14       s15    Movie                                     3022
# 27       s28    Movie                                   #Alive
# 28       s29    Movie            #AnneFrank - Parallel Stories
# ...      ...      ...                                      ...
# 7762   s7761    Movie                                Zaki Chan
# 7783   s7782    Movie                                     Zoom
# 7784   s7783    Movie                                     Zozo
# 7786   s7785    Movie                        Zulu Man in Japan
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                          Director  \
# 4                  Robert Luketic
# 6                 Yasir Al Yasiri
# 14                     John Suits
# 27                         Cho Il
# ...

# %% [markdown]
# ### Q. 5) Show only the Titles of all TV Shows that were released in India only.

# %%
df_netflix[(df_netflix['Category'] == 'TV Show') & (df_netflix['Country']=='India')]['Title']
# Out:
# 86            21 Sarfarosh: Saragarhi 1897
# 132                              7 (Seven)
# 340                           Agent Raghav
# 364                          AkbarÂ Birbal
# 533                    Anjaan: Rural Myths
#                        ...
# 6249                  The Creative Indians
# 6400    The Golden Years with Javed Akhtar
# 6469                The House That Made Me
# 7294                            Typewriter
# 7705                       Yeh Meri Family
# Name: Title, Length: 71, dtype: object

# %% [markdown]
# ### Q. 6) Show Top 10 Directors, who gave the highest number of TV Shows & Movies to Netflix ?

# %%
df_netflix['Director'].value_counts().head(10)
# Out:
# Director
# RaÃºl Campos, Jan Suter    18
# Marcus Raboy               16
# Jay Karas                  14
# Cathy Garcia-Molina        13
# Jay Chapman                12
# Youssef Chahine            12
# Martin Scorsese            12
# Steven Spielberg           10
# David Dhawan                9
# Hakan AlgÃ¼l                8
# Name: count, dtype: int64

# %% [markdown]
# ### Q. 7) Show all the Records, where "Category is Movie and Type is Comedies" or "Country is United Kingdom".

# %%
df_netflix[(df_netflix['Category'] =='Movie') & (df_netflix['Type']=='Comedies') |(df_netflix['Country']== 'United Kingdom')]
# Out:
#      Show_Id Category                   Title          Director  \
# 19       s20    Movie                     '89               NaN
# 33       s34    Movie            #realityhigh  Fernando Lebrija
# 58       s59  TV Show             100% Hotter               NaN
# 72       s73    Movie                17 Again       Burr Steers
# 82       s83    Movie     2036 Origin Unknown     Hasraf Dulull
# ...      ...      ...                     ...               ...
# 7670   s7669  TV Show  World War II in Colour               NaN
# 7671   s7670  TV Show  World's Busiest Cities               NaN
# 7688   s7687    Movie  XV: Beyond the Tryline  Pierre Deschamps
# 7725   s7724    Movie            You Can Tutu       James Brown
# 7740   s7739  TV Show         Young Wallander               NaN
#
#                                                    Cast         Country  \
# 19                   Lee Dixon, Ian Wright, Paul Merson  United Kingdom
# ...

# %% [markdown]
# ### Q. 8) In how many movies/shows, Tom Cruise was cast ?

# %%
df_netflix[df_netflix['Cast'].str.contains('Tom Cruise')]
# Out:
#      Show_Id Category     Title              Director  \
# 3860   s3861    Movie  Magnolia  Paul Thomas Anderson
# 5071   s5071    Movie  Rain Man        Barry Levinson
#
#                                                    Cast        Country  \
# 3860  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...  United States
# 5071  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#          Release_Date Rating Duration                        Type  \
# 3860  January 1, 2020      R  189 min  Dramas, Independent Movies
# 5071     July 1, 2019      R  134 min      Classic Movies, Dramas
#
#                                             Description Release Year    Year
# 3860  Through chance, human action, past history and...   2020-01-01  2020.0
# 5071  A fast-talking yuppie is forced to slow down w...   2019-07-01  2019.0

# %%
#df_netflix.dropna(subset=['Cast'],inplace=True)
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_14492\1407353321.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_netflix.dropna(subset=['Cast'],inplace=True)

# %% [markdown]
# ### Q. 9) What are the different Ratings defined by Netflix ?

# %%
df_netflix.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  JoÃ£o Miguel, Bianca Comparato, Michel Gomes, ...         Brazil
# 1  DemiÃ¡n Bichir, HÃ©ctor Bonilla, Oscar Serrano...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
df_netflix['Rating'].unique()
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-PG', 'TV-G', 'TV-Y', 'NR', nan,
#        'TV-Y7', 'PG', 'G', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %% [markdown]
# ### Q. 9.1) How many Movies got the 'TV-14' rating, in Canada ?

# %%
df_netflix[(df_netflix['Category']== 'Movie') & (df_netflix['Country']=='Canada')&(df_netflix['Rating']=='TV-14')].shape
# Out:
# (9, 13)

# %% [markdown]
# ### Q. 9.2) How many TV Shows got the 'R' rating, after year 2018 ?

# %%
df_netflix[(df_netflix['Category']== 'TV Show') & (df_netflix['Rating']=='R')& (df_netflix['Year']> 2018.0)]
# Out:
#      Show_Id Category                                Title           Director  \
# 6437   s6436  TV Show  The Hateful Eight: Extended Version  Quentin Tarantino
#
#                                                    Cast Country  \
# 6437  Samuel L. Jackson, Kurt Russell, Jennifer Jaso...     NaN
#
#         Release_Date Rating  Duration      Type  \
# 6437  April 25, 2019      R  1 Season  TV Shows
#
#                                             Description Release Year    Year
# 6437  Trapped at a stagecoach stop as a storm rages ...   2019-04-25  2019.0

# %% [markdown]
#  ### Q. 10) What is the maximum duration of a Movie/Show on Netflix ?

# %%
df_netflix.Duration.unique()
# Out:
# array(['4 Seasons', '93 min', '78 min', '80 min', '123 min', '1 Season',
#        '95 min', '119 min', '118 min', '143 min', '103 min', '89 min',
#        '91 min', '149 min', '144 min', '124 min', '87 min', '110 min',
#        '128 min', '117 min', '100 min', '2 Seasons', '99 min', '102 min',
#        '104 min', '105 min', '125 min', '81 min', '97 min', '106 min',
#        '107 min', '109 min', '44 min', '101 min', '90 min', '3 Seasons',
#        '37 min', '113 min', '114 min', '130 min', '94 min', '140 min',
#        '135 min', '82 min', '70 min', '121 min', '92 min', '164 min',
#        '83 min', '116 min', '84 min', '86 min', '120 min', '96 min',
#        '126 min', '75 min', '129 min', '77 min', '137 min', '148 min',
#        '122 min', '176 min', '85 min', '22 min', '68 min', '111 min',
#        '29 min', '142 min', '168 min', '21 min', '59 min', '98 min',
#        '108 min', '26 min', '156 min', '28 min', '57 min', '150 min',
# ...

# %%
df_netflix.Duration.dtypes
# Out:
# dtype('O')

# %%
## we will split the duration column into 2 columns, one that contains the duration in minutes and second one in seasons

# %%
df_netflix[['Minutes','Unit']]= df_netflix['Duration'].str.split(' ',expand= True)
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_14492\1321198506.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_netflix[['Minutes','Unit']]= df_netflix['Duration'].str.split(' ',expand= True)
# C:\Users\ACER\AppData\Local\Temp\ipykernel_14492\1321198506.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_netflix[['Minutes','Unit']]= df_netflix['Duration'].str.split(' ',expand= True)

# %%
df_netflix.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  JoÃ£o Miguel, Bianca Comparato, Michel Gomes, ...         Brazil
# 1  DemiÃ¡n Bichir, HÃ©ctor Bonilla, Oscar Serrano...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
df_netflix['Minutes'].max()
# Out:
# '99'

# %% [markdown]
# ### Q. 11) Which individual country has the Highest No. of TV Shows ?

# %%
df_tv_shows = df_netflix[df_netflix['Category']=='TV Show']

# %%
df_tv_shows
# Out:
#      Show_Id Category                                  Title     Director  \
# 0         s1  TV Show                                     3%          NaN
# 5         s6  TV Show                                     46  Serdar Akar
# 11       s12  TV Show                                   1983          NaN
# 16       s17  TV Show                                 Feb-09          NaN
# 24       s25  TV Show  âSAINT SEIYA: Knights of the Zodiac          NaN
# ...      ...      ...                                    ...          ...
# 7761   s7760  TV Show                              Zak Storm          NaN
# 7769   s7768  TV Show                     Zindagi Gulzar Hai          NaN
# 7777   s7776  TV Show                             Zoids Wild          NaN
# 7781   s7780  TV Show                              Zona Rosa          NaN
# 7787   s7786  TV Show                  Zumbo's Just Desserts          NaN
#
#                                                    Cast  \
# ...

# %%
df_tv_shows.Country.value_counts().head(50)
# Out:
# Country
# United States                    581
# United Kingdom                   169
# Japan                            155
# South Korea                      145
# Taiwan                            68
# India                             57
# Canada                            53
# Australia                         41
# Spain                             40
# France                            36
# China                             36
# Mexico                            33
# Turkey                            27
# Brazil                            23
# Thailand                          22
# United States, Canada             21
# Colombia                          19
# Germany                           18
# Singapore                         17
# Argentina                         15
# Canada, United States             13
# Russia                            13
# Egypt                             12
# Italy                             11
# United Kingdom, United States     10
# ...

# %% [markdown]
# ### Q. 12) How can we sort the dataset by Year ?

# %%
df_netflix.sort_values(by='Year',ascending=False)
# Out:
#      Show_Id Category                         Title  \
# 2505   s2506    Movie                       Gothika
# 205     s206    Movie               A Monster Calls
# 3558   s3559    Movie                         Leap!
# 3544   s3545  TV Show         Last Tango in Halifax
# 6502   s6501    Movie              The Intouchables
# ...      ...      ...                           ...
# 3374   s3375  TV Show                      Kikoriki
# 3492   s3493  TV Show           La Familia P. Luche
# 3946   s3947  TV Show                         Maron
# 5138   s5138  TV Show                  Red vs. Blue
# 6066   s6066  TV Show  The Adventures of Figaro Pho
#
#                              Director  \
# 2505                Mathieu Kassovitz
# 205                       J.A. Bayona
# 3558         Eric Summer, Ãric Warin
# 3544                       Juliet May
# 6502  Olivier Nakache, Ãric Toledano
# ...                               ...
# 3374                              NaN
# ...

# %% [markdown]
# ### Q. 13) Find all the instances where: Category is 'Movie' and Type is 'Dramas' or Category is 'TV Show' & Type is 'Kids' TV'.

# %%
df_netflix[(df_netflix['Category']== 'Movie') &  (df_netflix['Type']== 'Dramas') | (df_netflix['Category']=='TV Show') & (df_netflix['Type']== "Kids' TV")]
# Out:
#      Show_Id Category                       Title        Director  \
# 4         s5    Movie                          21  Robert Luketic
# 7         s8    Movie                         187  Kevin Reynolds
# 111     s112  TV Show                     44 Cats             NaN
# 170     s171    Movie                A Family Man   Mark Williams
# 232     s233    Movie  A Stoning in Fulham County   Larry Elikann
# ...      ...      ...                         ...             ...
# 7668   s7667  TV Show               World of Winx  Iginio Straffi
# 7717   s7716  TV Show                        Yoko             NaN
# 7719   s7718  TV Show                         YOM             NaN
# 7758   s7757  TV Show                          Z4             NaN
# 7761   s7760  TV Show                   Zak Storm             NaN
#
#                                                    Cast  \
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# 7     Samuel L. Jackson, John Heard, Kelly Rowan, Cl...
# ...
